# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils.utils import color
from utils.recommendation import Recommendations

neo4j_settings = {
    "connection_url": "bolt://localhost:7687",
    "username": "neo4j",
    "password": "augmentor2024",
}

openai_settings = {
    "model_name": "gpt-3.5-turbo-0125",  # Choices: ["gpt-3.5-turbo", "gpt-3.5-turbo-0125"]
    "temperature": 0,
    "api_key": "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",
}

user_settings = {"name": "Vilma", "title": "Educator", "username": "User"}


AI_Assistant = Recommendations(
    neo4j_settings=neo4j_settings,
    openai_settings=openai_settings,
    cypher_corrector=True,
    user_settings=user_settings,
    recommendations_file="./Resources/recommendations.json",    
    # recommendations_db_path = "Resources/recommendations_db",
    # room_descriptions_db_path = "Resources/room_descriptions_db",
    language="English",
    verbose=True,
)
# Out:
# [INFO] Connection with Neo4j established

# %%
import textwrap

def show(response:str)->None:
    print()
    print(color.BLUE + "\nResponse: " + color.END, end = "")
    for text in response.split("\n"):
        print("{}".format(textwrap.fill(text, width=170)))

# %% [markdown]
# ### Case study 1
#
# Basic functionalities (offensive language, irrelevant questions, retrieve grades)

# %%
question = "Give the performance of funcking Learner with username 'dada'"
response = AI_Assistant.query(question)

show(response)
# Out:
# Offensive content
# Explanation: The question contains an offensive word 'funcking'.
#
#
# Response: Offensive content
# Explanation: The question contains an offensive word 'funcking'.

# %%
d_recommendations = AI_Assistant.recommendation()

for key, value in d_recommendations.items(): 
    show(value)
    print(color.GREEN + "To: " + color.END, key)
# Out:
# Response: Dear Vilma,
#
# Regarding your query about the performance of the learner with the username 'dada', I would like to recommend refraining from using offensive language in your
# communication. The use of the word 'funcking' in your query is inappropriate and can be considered offensive.
#
# It is important to maintain a professional and respectful tone in all forms of communication, especially when discussing students or their performance. By using language
# that is respectful and appropriate, you can create a positive and inclusive learning environment for all individuals involved.
#
# I recommend revising your query to remove any offensive content and to ensure that your language is professional and respectful at all times.
#
# Kind regards,
# To:  User

# %%
question = "How old is timothy?"
response = AI_Assistant.query(question)

show(response)
# Out:
# Not offensive content
# Query: How old is timothy?
#
#
# Response: The question is probably irrelevant. Please try again.

# %%
d_recommendations = AI_Assistant.recommendation()

for key, value in d_recommendations.items(): 
    show(value)
    print(color.GREEN + "To: " + color.END, key)
# Out:
# Response: Dear Vilma,
#
# I recommend updating the query to focus on topics related to the learning process in the class. Asking about Timothy's age may not be relevant to the educational
# objectives we are aiming to achieve. Please consider formulating queries that are more aligned with the curriculum and student learning outcomes.
#
# Kind regards,
# To:  User

# %%
question = "Give the scores of all Learners at each room. Summarize results per learner"
response = AI_Assistant.query(question)

show(response)
# Out:
# Not offensive content
# Query: Give the grades of all Learners at each room. Summarize results per learner
#
#
# Response: The question is probably irrelevant. Please try again.

# %%
d_recommendations = AI_Assistant.recommendation()

for key, value in d_recommendations.items(): 
    show(value)
    print(color.GREEN + "To: " + color.END, key)
# Out:
# Response: Dear Vilma,
#
# I recommend updating the query to focus on more relevant information related to the learning process. It would be more beneficial to inquire about specific assessments,
# progress reports, or areas of improvement for each learner. This will provide more valuable insights and help in better understanding the students' academic performance.
#
# Kind regards,
# To:  User

# %%
question = "Give the scores of Learner with username: djdo at each room"
response = AI_Assistant.query(question)

show(response)
# Out:
# Not offensive content
# Query: Give the grades of Learner with username: djdo at each room
# Generated Cypher:
# MATCH (l:LEARNER)-[r:REGISTERED]->(n:ROOM) WHERE l.username='djdo' RETURN l.username AS username, n.code AS Room_Code, r.score AS Grade
# Response:
#
# ...

# %%
d_recommendations = AI_Assistant.recommendation()

for key, value in d_recommendations.items(): 
    show(value)
    print(color.GREEN + "To: " + color.END, key)
# Out:
# response:  (['djdo'], None)
# Recommendations to Learners: ['djdo']
# Recommendations to Profile:  None
#
#
# Response: Dear djdo,
#
# After reviewing your grades in each room, it is evident that there are several resources that you have not studied yet or have not performed well in. It is crucial for
# your progress to focus on these resources and dedicate more time to studying them in order to improve your grades.
#
# I recommend that you prioritize studying the following resources that you have not studied or scored low in:
# - hashingcrypto101
# - tornetwork
# - hellopt
# - pythonbasicsuf
# - catregexuu
# - phishingemails1tryoe32
# - openvpn3b
# - careersincyber
# - thelayoftheland
# - phishingemails1tryoe
# - btwindowsinternals
# - yara
# - tutorial
#
# Additionally, I suggest that you engage with your colleagues in the forum to discuss any difficulties you may be facing while studying. Collaborating with others can
# ...

# %%
question = "Give the description of room with title 'Hashing - Crypto 101'"
response = AI_Assistant.query(question)

show(response)
# Out:
# Not offensive content
# Query: Give the description of room with title 'Hashing - Crypto 101'
# Generated Cypher:
# MATCH (r:ROOM {title: 'Hashing - Crypto 101'}) RETURN r.description as Description
# Response:
#
# [{'Description': 'An introduction to Hashing, as part of a series on crypto'}]
#
#
# Response: - An introduction to Hashing, as part of a series on crypto

# %%
question = "Give the titles and descriptions of all modules. Reply in format Title: <title> | Description: <description>"
response = AI_Assistant.query(question)

show(response)
# Out:
# Not offensive content
# Query: Give the titles and descriptions of all modules. Reply in format Title: <title> | Description: <description>
# Generated Cypher:
# MATCH (m:MODULE)
# RETURN m.title AS Title, m.summary AS Description
# Response:
#
# ...

# %% [markdown]
# ### Case study 2
#
# - Retrieve information about learner's performance

# %%
question = """Give me the paths that learner with username 'djdo' has registerd and their percentage of completeness. Reply in the form path | percentage"""
response = AI_Assistant.query(question)

print(color.BLUE + "\nResponse: " + color.END, end = "")
print(response)
# Out:
# Not offensive content
# Query: Give me the paths that learner with username 'djdo' has registerd and their percentage of completeness. Reply in the form path | percentage
# Generated Cypher:
# MATCH (l:LEARNER)-[r:REGISTERED_ROOM]->(p:PATH) WHERE l.username='djdo' RETURN p.title AS path, r.percentage_completeness AS percentage
# Response:
#
# [{'path': 'Offensive Pentesting', 'percentage': 0.0}, {'path': 'Introduction to Cyber Security', 'percentage': 50.0}, {'path': 'Jr Penetration Tester', 'percentage': 8.6}, {'path': 'Pre Security', 'percentage': 40.0}, {'path': 'SOC Level 1', 'percentage': 0.0}, {'path': 'Red Teaming', 'percentage': 0.0}, {'path': 'Complete Beginner', 'percentage': 3.3}, {'path': 'Web Fundamentals', 'percentage': 4.3}, {'path': 'Cyber Defense', 'percentage': 0.0}]
#
# Response: - Introduction to Cyber Security | 50.0%
# - Jr Penetration Tester | 8.6%
# - Pre Security | 40.0%
# - Complete Beginner | 3.3%
# - Web Fundamentals | 4.3%

# %%
d_recommendations = AI_Assistant.recommendation()

for key, value in d_recommendations.items(): 
    show(value)
    print(color.GREEN + "To: " + color.END, key)
# Out:
# response:  (['djdo'], None)
# Recommendations to Learners: ['djdo']
# Recommendations to Profile:  None
#
#
# Response: Dear djdo,
#
# I have reviewed your progress in the various paths you have registered for and I would like to provide you with some customized recommendations.
#
# Firstly, I recommend focusing on completing the courses you have started but not yet finished, such as "Jr Penetration Tester", "Complete Beginner", and "Web
# Fundamentals". By dedicating more time and effort to these courses, you can improve your overall understanding and grades.
#
# Additionally, I suggest that you study hard and devote more time to the learning material in order to enhance your knowledge and skills in the respective subjects.
# Consistent effort and practice will help you achieve better results.
#
# Furthermore, I encourage you to engage with your colleagues in the forum to discuss any difficulties you may be facing. Collaborating with others can provide valuable
# ...

# %%
question = """Give me the modules that learner with username 'djdo' has registerd and sort them by the percentage of completeness"""
response = AI_Assistant.query(question)

print(color.BLUE + "\nResponse: " + color.END, end = "")
print(response)
# Out:
# Not offensive content
# Query: Give me the modules that learner with username 'djdo' has registerd and sort them by the percentage of completeness
# Generated Cypher:
# MATCH (l:LEARNER)-[r:REGISTERED_MODULE]->(m:MODULE)
# WHERE l.username='djdo'
# RETURN m.moduleURL AS Module_Title, r.percentage_completeness AS Percentage
# ORDER BY Percentage
# Response:
#
# ...

# %%
question = """Give me the modules that learner with username 'djdo' has registerd and the percentage of completeness"""
response = AI_Assistant.query(question)

print(color.BLUE + "\nResponse: " + color.END, end = "")
print(response)
# Out:
# Not offensive content
# Query: Give me the modules that learner with username 'djdo' has registerd and the percentage of completeness
# Generated Cypher:
# MATCH (l:LEARNER)-[r:REGISTERED_MODULE]->(m:MODULE)
# WHERE l.username='djdo'
# RETURN m.title AS Module_Title, r.percentage_completeness AS Percentage
# Response:
#
# ...

# %%
d_recommendations = AI_Assistant.recommendation()

for key, value in d_recommendations.items(): 
    show(value)
    print(color.GREEN + "To: " + color.END, key)
# Out:
# response:  (['djdo'], None)
# Recommendations to Learners: ['djdo']
# Recommendations to Profile:  None
#
#
# Response: Dear djdo,
#
# I have reviewed your progress in the modules you have registered for and would like to provide you with some recommendations for improvement.
#
# It seems that you have completed Introduction to Cyber Security with 100.0% completeness, which is excellent. However, there are some modules where your progress is
# lower. I recommend that you focus on studying Network Fundamentals, Web Hacking Fundamentals, and How The Web Works as they have completion percentages of 40.0%, 14.3%,
# and 25.0% respectively.
#
# To improve your grades, I suggest dedicating more time to studying the learning material and seeking help from your colleagues in the forum if you encounter any
# difficulties. By discussing with others, you can gain different perspectives and insights that may help you better understand the topics.
#
# ...

# %%
question = """Give me information about the performance of learner with username JolantaD in rooms: 'Hashing - Crypto 101', 'careersincyber' and 'phishingemails1tryoe'"""
response = AI_Assistant.query(question)

print(color.BLUE + "\nResponse: " + color.END, end = "")
print(response)
# Out:
# Not offensive content
# Query: Give me information about the performance of learner with username JolantaD in rooms: 'Hashing - Crypto 101', 'careersincyber' and 'phishingemails1tryoe'
# (<username>, <profile>, <room_code>, <module_URL>, <path_code>, <suggestion>) = ('JolantaD', None, ['Hashing - Crypto 101', 'careersincyber', 'phishingemails1tryoe'], None, None, False)
# ('JolantaD', None, ['Hashing - Crypto 101', 'careersincyber', 'phishingemails1tryoe'], None, None, False)
# Username: JolantaD
# Profile:  None
# Room code: ['Hashing - Crypto 101', 'careersincyber', 'phishingemails1tryoe']
# Module URL: None
# Path code: None
# Suggestion: False
#
# Response: ### Room: Hashing - Crypto 101
# No information can be provided for learner: JolantaD
# --------------------------------------------------------------------------------
#
# ### Room: careersincyber
# Status: Completed
# Score: 0/560
# Number of correctly answered questions: 9/9
#
# ...

# %%
d_recommendations = AI_Assistant.recommendation()

for key, value in d_recommendations.items(): 
    show(value)
    print(color.GREEN + "To: " + color.END, key)
# Out:
# Response: Dear Learner,
#
# Room: phishingemails1tryoe
# Performance: You have answered incorrectly in all questions for each task in the room "phishingemails1tryoe".
# Recommendation: I recommend you to carefully review the resources provided in the room, including the videos and tutorials, to improve your understanding of the
# components that make up an email. Pay close attention to the details and make sure to understand the correct answers to the questions asked in each task.
#
# Kind regards,
# Vilma
# Educator
#
#
# ----------------------------------------------------------------------------------------------------
# # Room: phishingemails1tryoe
#
# ## Video resources
# Title: How to write professional emails in English
# URL: https://www.youtube.com/watch?v=3Tu1jN65slw
#
# Title: English for Emails: Email addresses
# URL: https://www.youtube.com/watch?v=OyiYMpLyAEE
#
# Title: Learn English | Introduction to Email Writing
# URL: https://www.youtube.com/watch?v=sksW-3J90vE
#
# ...

# %%
question = """Give me information about the performance of learner with username djdo in module with url 'network-fundamentals'"""
response = AI_Assistant.query(question)

print(color.BLUE + "\nResponse: " + color.END, end = "")
print(response)
# Out:
# Not offensive content
# Query: Give me information about the performance of learner with username djdo in module with url 'network-fundamentals'
# (<username>, <profile>, <room_code>, <module_URL>, <path_code>, <suggestion>) = ('djdo', None, None, 'network-fundamentals', None, False)
# ('djdo', None, None, 'network-fundamentals', None, False)
# Username: djdo
# Profile:  None
# Room code: None
# Module URL: ['network-fundamentals']
# Path code: None
# Suggestion: False
#
# Response: ## Module: network-fundamentals
# Learner: djdo has been registered to 100.0% of rooms of this module and completed 40.0% of the rooms
#
# ### Room: whatisnetworking
# Status: Completed
# Score: 80/560
# Number of correctly answered questions: 21/21
# --------------------------------------------------------------------------------
#
# ### Room: introtolan
# Status: Completed
# Score: 152/560
# Number of correctly answered questions: 20/20
# ...

# %%
d_recommendations = AI_Assistant.recommendation()

for key, value in d_recommendations.items(): 
    show(value)
    print(color.GREEN + "To: " + color.END, key)
# Out:
# Response: Dear Learner,
#
# Based on the information provided, you have completed two rooms in the network-fundamentals module with varying scores and correctly answered questions. To improve your
# performance, I recommend studying the resources (videos and tutorials) of the rooms you have not completed yet.
#
# For the room "osimodelzi", I suggest focusing on learning about the OSI model and how data is handled across a network. Understanding this fundamental networking
# framework will help you grasp the various stages of data transmission.
#
# In the room "packetsframes", it would be beneficial to study how data is divided into smaller pieces and transmitted across a network. This knowledge is essential in
# understanding the process of data transfer between devices.
#
# Lastly, for the room "extendingyournetwork", exploring the technologies used to extend networks onto the Internet and the motivations behind this can enhance your
# understanding of network expansion.
#
# ...

# %%
question = """Give me information about learner with username djdo in path 'presecurity'"""
response = AI_Assistant.query(question)

print(color.BLUE + "\nResponse: " + color.END, end = "")
print(response)
# Out:
# Not offensive content
# Query: Give me information about learner with username djdo in path 'presecurity'
# (<username>, <profile>, <room_code>, <module_URL>, <path_code>, <suggestion>) = ('djdo', None, None, None, 'presecurity', False)
# ('djdo', None, None, None, 'presecurity', False)
# Username: djdo
# Profile:  None
# Room code: None
# Module URL: None
# Path code: ['presecurity']
# Suggestion: False
#
# Response: # Path: presecurity
# Learner: djdo has been registered to 100.0% of rooms of this path and completed 40.0% of the rooms
#
# ## Module: introduction-to-cyber-security
# Learner: djdo has been registered to 100.0% of rooms of this module and completed 100.0% of the rooms
#
# ### Room: introtooffensivesecurity
# Status: Completed
# Score: 16/560
# Number of correctly answered questions: 5/5
# --------------------------------------------------------------------------------
#
# ### Room: defensivesecurity
# Status: Completed
# Score: 40/560
# ...

# %%
d_recommendations = AI_Assistant.recommendation()

for key, value in d_recommendations.items(): 
    show(value)
    print(color.GREEN + "To: " + color.END, key)
# Out:
# Response: Dear Learner,
#
# Based on the information provided, it seems that you have completed some rooms with varying scores and correctly answered questions. To improve your performance, I
# recommend studying the resources (videos and tutorials) of the following rooms:
#
# 1. Room: osimodelzi
#    - Room Description: Learn about the fundamental networking framework that determines the various stages in which data is handled across a network.
#    - Recommendation: By studying this room, you can gain a better understanding of the OSI model and how data is processed in a network.
#
# 2. Room: packetsframes
#    - Room Description: Understand how data is divided into smaller pieces and transmitted across a network to another device.
#    - Recommendation: Studying this room will help you grasp the concept of data transmission in networking, which is essential for understanding network communication.
#
# 3. Room: linuxfundamentalspart1
# ...

# %% [markdown]
# ### Case study 3
#
# - Select room

# %%
question = """Give me information which room to select for learning about 'AWS technologies' for learner with username djdo"""
response = AI_Assistant.query(question)

print(color.BLUE + "\nResponse:\n" + color.END, end = "")
print(response)
# Out:
# Not offensive content
# Query: Give me information which room to select for learning about 'AWS technologies' for learner with username djdo
# (<username>, <profile>, <room_code>, <module_URL>, <path_code>, <suggestion>) = ('djdo', None, None, None, None, True)
# ('djdo', None, None, None, None, True)
# Username: djdo
# Profile:  None
# Room code: None
# Module URL: None
# Path code: None
# Suggestion: True
# ['careersincyber', 'defensivesecurity', 'introtooffensivesecurity', 'whatisnetworking', 'introtolan', 'howwebsiteswork']
# awsbasicconcepts 0.33426535
# attackingdefendingvpcs 0.3548363
# nislinuxone 0.3848835
# cloud101aws 0.3890154
# linuxstrengthtraining 0.39021015
# ...

# %%
d_recommendations = AI_Assistant.recommendation()

for key, value in d_recommendations.items(): 
    show(value)
    print(color.GREEN + "To: " + color.END, key)
# Out:
# Response: Dear Learner,
#
# Room: awsbasicconcepts
# Recommendation: This room covers the basic concepts relevant to Amazon Web Services (AWS), which will provide a solid foundation for learning about AWS technologies.
# Relevance: 100%
#
# Room: attackingdefendingvpcs
# Recommendation: This room focuses on the basics of AWS Virtual Private Cloud (VPC), which is a key component of AWS technologies.
# Relevance: 80%
#
# Please study the resources (videos and tutorial of each room) for improving your performance and feel free to contact the educator for any assistance you may need.
#
# Kind regards,
# Vilma
# Educator
#
#
# ----------------------------------------------------------------------------------------------------
#
# To:  djdo

# %%
question = """Give me information which room to select for learning about 'creating cup-cakes for children'"""
response = AI_Assistant.query(question)

print(color.BLUE + "\nResponse:\n" + color.END, end = "")
print(response)
# Out:
# Not offensive content
# Query: Give me information which room to select for learning about 'creating cup-cakes for children'
# (<username>, <profile>, <room_code>, <module_URL>, <path_code>, <suggestion>) = (None, None, None, None, None, True)
# (None, None, None, None, None, True)
# Username: None
# Profile:  None
# Room code: None
# Module URL: None
# Path code: None
# Suggestion: True
# redteamcapstonechallenge 0.37310934
# chocolatefactory 0.38899067
# socintwithoutlogin 0.39784628
# nahamstore 0.40350088
# nislinuxone 0.40685225
# Suggested rooms: {'query': "Give me information which room to select for learning about 'creating cup-cakes for children'", 'information': '- Room code: redteamcapstonechallenge. Description: This room is the capstone challenge for the red team learning pathway..\n', 'text': 'There are no available rooms for the requested subject.'}
#
# Response:
# There are no available rooms for the requested subject.

# %%
d_recommendations = AI_Assistant.recommendation()

for key, value in d_recommendations.items(): 
    show(value)
    print(color.GREEN + "To: " + color.END, key)
# Out:
# Response: Dear Learner,
#
# Unfortunately, there are currently no available rooms for the subject you are interested in improving your knowledge on.
#
# Kind regards,
# Vilma
# Educator
#
#
# ----------------------------------------------------------------------------------------------------
#
# To:  None
